# %% [markdown]
# # TASK 1

# %% [markdown]
# ### Importing Liberary

# %%
### importing warnings for future warnings should be ignored
import warnings
warnings.filterwarnings('ignore')

### importing numpy for any statistical information 
import numpy as np 

### importing pandas for doing all EDA
import pandas as pd 

### Importing matplotlib and seaborn for visualization in python
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Dataset

# %%
### importing customer address dataste

anz=pd.read_excel('ANZ synthesised transaction dataset.xlsx')

### checking first 5 rows of the data
anz.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# ...

# %%
print('The Shape of Dataset is ', anz.shape)
# Out:
# The Shape of Dataset is  (12043, 23)

# %%
anz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float64
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float64
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float64
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int64
#  14  merchant_suburb    7717 non-null   object
# ...

# %%
anz.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount
# count  12043.000000
# mean     187.933588
# std      592.599934
# min        0.100000
# 25%       16.000000
# 50%       29.000000
# 75%       53.655000
# max     8835.980000

# %%
anz.describe(include='object').T
# Out:
#                    count unique                                   top   freq
# status             12043      2                            authorized   7717
# bpay_biller_code     885      3                                     0    883
# account            12043    100                        ACC-1598451071    578
# currency           12043      1                                   AUD  12043
# long_lat           12043    100                         153.41 -27.95    578
# txn_description    12043      6                             SALES-POS   3934
# merchant_id         7717   5725  106e1272-44ab-4dcb-a438-dd98e0071e51     14
# first_name         12043     80                               Michael    746
# gender             12043      2                                     M   6285
# merchant_suburb     7717   1609                             Melbourne    255
# merchant_state      7717      8                                   NSW   2169
# ...

# %%
anz['date'].nunique()
# Out:
# 91

# %%
anz['card_present_flag'].value_counts()
# Out:
# 1.0    6194
# 0.0    1523
# Name: card_present_flag, dtype: int64

# %%
anz['merchant_id'].value_counts()
# Out:
# 106e1272-44ab-4dcb-a438-dd98e0071e51    14
# 6c84c219-96ea-4c6f-9de5-0a28bcaec62f    12
# e28c426d-cbef-4e2d-aa06-1ba0b6b1902f    11
# 6ddddc40-5b69-4253-8a26-167999a8bf96    10
# aef30de1-c67e-4ab7-8577-2931a4bf3c7e    10
#                                         ..
# e9f8880c-2050-4365-85df-2d7207959319     1
# af074c2f-0f00-4fd6-8bae-9431f12f099a     1
# de97b8b9-1816-4f66-ba7e-3df5e621e634     1
# 65db74fb-6e0a-4d76-9c2d-dd96c66de08b     1
# 7a57eefe-cbd1-4629-ac0e-722f9ee66fe9     1
# Name: merchant_id, Length: 5725, dtype: int64

# %%
anz['merchant_state'].value_counts()
# Out:
# NSW    2169
# VIC    2131
# QLD    1556
# WA     1100
# SA      415
# NT      205
# ACT      73
# TAS      68
# Name: merchant_state, dtype: int64

# %%
anz['long_lat']
# Out:
# 0        153.41 -27.95
# 1        153.41 -27.95
# 2        151.23 -33.94
# 3        153.10 -27.66
# 4        153.41 -27.95
#              ...
# 12038    149.83 -29.47
# 12039    151.22 -33.87
# 12040    151.12 -33.89
# 12041    144.96 -37.76
# 12042    150.92 -33.77
# Name: long_lat, Length: 12043, dtype: object

# %%
anz['merchant_long_lat'].value_counts()
# Out:
# 151.21 -33.87    145
# 144.96 -37.82     85
# 144.97 -37.81     59
# 144.96 -37.81     56
# 153.02 -27.47     46
#                 ...
# 144.9 -37.76       1
# 138.66 -34.85      1
# 152.94 -27.53      1
# 150.72 -34.99      1
# 145.53 -37.78      1
# Name: merchant_long_lat, Length: 2703, dtype: int64

# %%
anz['extraction']
# Out:
# 0        2018-08-01T01:01:15.000+0000
# 1        2018-08-01T01:13:45.000+0000
# 2        2018-08-01T01:26:15.000+0000
# 3        2018-08-01T01:38:45.000+0000
# 4        2018-08-01T01:51:15.000+0000
#                      ...
# 12038    2018-10-31T23:09:06.000+0000
# 12039    2018-10-31T23:21:46.000+0000
# 12040    2018-10-31T23:34:25.000+0000
# 12041    2018-10-31T23:47:05.000+0000
# 12042    2018-10-31T23:59:44.000+0000
# Name: extraction, Length: 12043, dtype: object

# %%
anz[['amount','balance']].describe()
# Out:
#              amount        balance
# count  12043.000000   12043.000000
# mean     187.933588   14704.195553
# std      592.599934   31503.722652
# min        0.100000       0.240000
# 25%       16.000000    3158.585000
# 50%       29.000000    6432.010000
# 75%       53.655000   12465.945000
# max     8835.980000  267128.520000

# %%
anz.groupby('customer_id')['amount','balance'].describe().T
# Out:
# customer_id    CUS-1005756958  CUS-1117979751  CUS-1140341822  CUS-1147642491  \
# amount  count       73.000000      100.000000       80.000000      118.000000
#         mean       222.862603      339.843700      212.632500      245.600169
#         std        354.888129      948.752608      527.052170      521.808054
#         min          6.480000        5.640000        4.090000        8.780000
#         25%         19.620000       17.760000       12.390000       29.902500
#         50%         39.270000       40.000000       25.620000       46.000000
#         75%        156.000000       55.000000       90.000000      122.072500
#         max        970.470000     3578.650000     1916.510000     1711.390000
# balance count       73.000000      100.000000       80.000000      118.000000
#         mean      2275.852055     9829.929000     5699.212250     9032.841186
#         std       2428.268431     3854.090508     1952.498319     3962.424965
# ...

# %%
anz[['long_lat','merchant_long_lat']].describe()
# Out:
#              long_lat merchant_long_lat
# count           12043              7717
# unique            100              2703
# top     153.41 -27.95     151.21 -33.87
# freq              578               145

# %%
anz['customer_id'].nunique()
# Out:
# 100

# %%
anz['transaction_id'].nunique()
# Out:
# 12043

# %%
anz['account'].nunique()
# Out:
# 100

# %%
anz['txn_description'].value_counts()
# Out:
# SALES-POS     3934
# POS           3783
# PAYMENT       2600
# PAY/SALARY     883
# INTER BANK     742
# PHONE BANK     101
# Name: txn_description, dtype: int64

# %%
anz['country'].value_counts()
# Out:
# Australia    12043
# Name: country, dtype: int64

# %%
anz.columns
# Out:
# Index(['status', 'card_present_flag', 'bpay_biller_code', 'account',
#        'currency', 'long_lat', 'txn_description', 'merchant_id',
#        'merchant_code', 'first_name', 'balance', 'date', 'gender', 'age',
#        'merchant_suburb', 'merchant_state', 'extraction', 'amount',
#        'transaction_id', 'country', 'customer_id', 'merchant_long_lat',
#        'movement'],
#       dtype='object')

# %%
anz.isnull().sum()[anz.isnull().sum()!=0]
# Out:
# card_present_flag     4326
# bpay_biller_code     11158
# merchant_id           4326
# merchant_code        11160
# merchant_suburb       4326
# merchant_state        4326
# merchant_long_lat     4326
# dtype: int64

# %%
anz['merchant_code'].value_counts()
# Out:
# 0.0    883
# Name: merchant_code, dtype: int64

# %%
ANZ=anz.drop(['bpay_biller_code','merchant_id','merchant_code','account','currency'],axis=1)
ANZ.head()
# Out:
#        status  card_present_flag       long_lat txn_description first_name  \
# 0  authorized                1.0  153.41 -27.95             POS      Diana
# 1  authorized                0.0  153.41 -27.95       SALES-POS      Diana
# 2  authorized                1.0  151.23 -33.94             POS    Michael
# 3  authorized                1.0  153.10 -27.66       SALES-POS     Rhonda
# 4  authorized                1.0  153.41 -27.95       SALES-POS      Diana
#
#    balance       date gender  age merchant_suburb merchant_state  \
# 0    35.39 2018-08-01      F   26         Ashmore            QLD
# 1    21.20 2018-08-01      F   26          Sydney            NSW
# 2     5.71 2018-08-01      M   38          Sydney            NSW
# 3  2117.22 2018-08-01      F   40         Buderim            QLD
# 4    17.95 2018-08-01      F   26   Mermaid Beach            QLD
#
#                      extraction  amount                    transaction_id  \
# ...

# %%
ANZ.head()
# Out:
#        status  card_present_flag       long_lat txn_description first_name  \
# 0  authorized                1.0  153.41 -27.95             POS      Diana
# 1  authorized                0.0  153.41 -27.95       SALES-POS      Diana
# 2  authorized                1.0  151.23 -33.94             POS    Michael
# 3  authorized                1.0  153.10 -27.66       SALES-POS     Rhonda
# 4  authorized                1.0  153.41 -27.95       SALES-POS      Diana
#
#    balance       date gender  age merchant_suburb merchant_state  \
# 0    35.39 2018-08-01      F   26         Ashmore            QLD
# 1    21.20 2018-08-01      F   26          Sydney            NSW
# 2     5.71 2018-08-01      M   38          Sydney            NSW
# 3  2117.22 2018-08-01      F   40         Buderim            QLD
# 4    17.95 2018-08-01      F   26   Mermaid Beach            QLD
#
#                      extraction  amount                    transaction_id  \
# ...

# %%
### creating transaction date column

# %%
ANZ['extraction'][548].split('T')[0]
# Out:
# '2018-08-04'

# %%
ANZ['Trans_date']=ANZ['extraction'].apply(lambda x: x.split('T')[0])

# %%
ANZ['Trans_date']=pd.to_datetime(ANZ['Trans_date'])

# %%
ANZ[['Trans_date','date']]
# Out:
#       Trans_date       date
# 0     2018-08-01 2018-08-01
# 1     2018-08-01 2018-08-01
# 2     2018-08-01 2018-08-01
# 3     2018-08-01 2018-08-01
# 4     2018-08-01 2018-08-01
# ...          ...        ...
# 12038 2018-10-31 2018-10-31
# 12039 2018-10-31 2018-10-31
# 12040 2018-10-31 2018-10-31
# 12041 2018-10-31 2018-10-31
# 12042 2018-10-31 2018-10-31
#
# [12043 rows x 2 columns]

# %%
ANZ.head()
# Out:
#        status  card_present_flag       long_lat txn_description first_name  \
# 0  authorized                1.0  153.41 -27.95             POS      Diana
# 1  authorized                0.0  153.41 -27.95       SALES-POS      Diana
# 2  authorized                1.0  151.23 -33.94             POS    Michael
# 3  authorized                1.0  153.10 -27.66       SALES-POS     Rhonda
# 4  authorized                1.0  153.41 -27.95       SALES-POS      Diana
#
#    balance       date gender  age merchant_suburb merchant_state  \
# 0    35.39 2018-08-01      F   26         Ashmore            QLD
# 1    21.20 2018-08-01      F   26          Sydney            NSW
# 2     5.71 2018-08-01      M   38          Sydney            NSW
# 3  2117.22 2018-08-01      F   40         Buderim            QLD
# 4    17.95 2018-08-01      F   26   Mermaid Beach            QLD
#
#                      extraction  amount                    transaction_id  \
# ...

# %%
#### creating Month column
ANZ['month'] = pd.DatetimeIndex(ANZ['Trans_date']).month

# %%
####  creating Day column 
ANZ['Day'] = pd.DatetimeIndex(ANZ['Trans_date']).weekday

# 0: Sunday
# 1:Monday this type structure etc.....

# %%
ANZ=ANZ.drop(['extraction'],axis=1)

# %%
ANZ.head(20)
# Out:
#         status  card_present_flag       long_lat txn_description first_name  \
# 0   authorized                1.0  153.41 -27.95             POS      Diana
# 1   authorized                0.0  153.41 -27.95       SALES-POS      Diana
# 2   authorized                1.0  151.23 -33.94             POS    Michael
# 3   authorized                1.0  153.10 -27.66       SALES-POS     Rhonda
# 4   authorized                1.0  153.41 -27.95       SALES-POS      Diana
# 5       posted                NaN  151.22 -33.87         PAYMENT     Robert
# 6   authorized                1.0  144.95 -37.76       SALES-POS    Kristin
# 7   authorized                1.0  144.95 -37.76             POS    Kristin
# 8   authorized                1.0  116.06 -32.00             POS      Tonya
# 9       posted                NaN  151.23 -33.96      INTER BANK    Michael
# 10      posted                NaN  146.94 -36.04         PAYMENT   Fernando
# ...

# %%
ANZ=ANZ.drop(['country','date'],axis=1)

# %%
ANZ['Trans_date'].nunique()
# Out:
# 91

# %%
ANZ['movement'].value_counts()
# Out:
# debit     11160
# credit      883
# Name: movement, dtype: int64

# %%
ANZ.head()
# Out:
#        status  card_present_flag       long_lat txn_description first_name  \
# 0  authorized                1.0  153.41 -27.95             POS      Diana
# 1  authorized                0.0  153.41 -27.95       SALES-POS      Diana
# 2  authorized                1.0  151.23 -33.94             POS    Michael
# 3  authorized                1.0  153.10 -27.66       SALES-POS     Rhonda
# 4  authorized                1.0  153.41 -27.95       SALES-POS      Diana
#
#    balance gender  age merchant_suburb merchant_state  amount  \
# 0    35.39      F   26         Ashmore            QLD   16.25
# 1    21.20      F   26          Sydney            NSW   14.19
# 2     5.71      M   38          Sydney            NSW    6.42
# 3  2117.22      F   40         Buderim            QLD   40.90
# 4    17.95      F   26   Mermaid Beach            QLD    3.25
#
#                      transaction_id     customer_id merchant_long_lat  \
# ...

# %%
print('The Shape of Dataset is ', ANZ.shape)
# Out:
# The Shape of Dataset is  (12043, 18)

# %%
ANZ.describe()
# Out:
#        card_present_flag        balance           age        amount  \
# count        7717.000000   12043.000000  12043.000000  12043.000000
# mean            0.802644   14704.195553     30.582330    187.933588
# std             0.398029   31503.722652     10.046343    592.599934
# min             0.000000       0.240000     18.000000      0.100000
# 25%             1.000000    3158.585000     22.000000     16.000000
# 50%             1.000000    6432.010000     28.000000     29.000000
# 75%             1.000000   12465.945000     38.000000     53.655000
# max             1.000000  267128.520000     78.000000   8835.980000
#
#               month           Day
# count  12043.000000  12043.000000
# mean       9.011957      3.085029
# std        0.816511      1.890169
# min        8.000000      0.000000
# 25%        8.000000      2.000000
# 50%        9.000000      3.000000
# 75%       10.000000      5.000000
# max       10.000000      6.000000

# %%
ANZ.describe(include='object')
# Out:
#             status       long_lat txn_description first_name gender  \
# count        12043          12043           12043      12043  12043
# unique           2            100               6         80      2
# top     authorized  153.41 -27.95       SALES-POS    Michael      M
# freq          7717            578            3934        746   6285
#
#        merchant_suburb merchant_state                    transaction_id  \
# count             7717           7717                             12043
# unique            1609              8                             12043
# top          Melbourne            NSW  327aeb5b04934a3e943c0c21da558087
# freq               255           2169                                 1
#
#            customer_id merchant_long_lat movement
# count            12043              7717    12043
# unique             100              2703        2
# top     CUS-2487424745     151.21 -33.87    debit
# freq               578               145    11160

# %%
ANZ.isnull().sum()[ANZ.isnull().sum()!=0]
# Out:
# card_present_flag    4326
# merchant_suburb      4326
# merchant_state       4326
# merchant_long_lat    4326
# dtype: int64

# %%
ANZ.groupby('gender')['card_present_flag'].describe()
# Out:
#          count      mean       std  min  25%  50%  75%  max
# gender
# F       3862.0  0.803211  0.397623  0.0  1.0  1.0  1.0  1.0
# M       3855.0  0.802075  0.398487  0.0  1.0  1.0  1.0  1.0

# %%
pd.DataFrame(ANZ.groupby(["status", 
                            "txn_description"])["card_present_flag"].value_counts()).T
# Out:
# status            authorized
# txn_description          POS      SALES-POS
# card_present_flag        1.0  0.0       1.0  0.0
# card_present_flag       3025  758      3169  765

# %%
ANZ['status'].value_counts().plot(kind='bar',alpha=0.3,color='green')
plt.show()

# %%
ANZ['merchant_state'].value_counts().plot(kind='bar',alpha=0.3,color='blue')
plt.show()

# %%
ANZ['gender'].value_counts().plot(kind='bar',alpha=0.3,color='red')
plt.show()

# %%
ANZ['movement'].value_counts().plot(kind='bar',alpha=0.3,color='yellow')
plt.show()

# %%
ANZ['txn_description'].value_counts()
# Out:
# SALES-POS     3934
# POS           3783
# PAYMENT       2600
# PAY/SALARY     883
# INTER BANK     742
# PHONE BANK     101
# Name: txn_description, dtype: int64

# %%
ANZ['txn_description'].value_counts().plot(kind='bar',alpha=0.3,color='green')
plt.show()

# %%
ANZ['Day'].value_counts().plot(kind='bar',alpha=0.3,color='black')
plt.show()

# %%
ANZ['month'].value_counts().plot(kind='bar',alpha=0.3,color='brown')
plt.show()

# %%
sns.boxenplot('month','amount',data=ANZ)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.boxenplot('Day','amount',data=ANZ)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot('Day','amount',data=ANZ)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.boxenplot('Day','balance',data=ANZ)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(ANZ['Trans_date'],ANZ['amount'])

# %%
#With POS 
customer1 = ANZ[ANZ['txn_description'].isin(['SALES-POS','POS'])]
customer1.head(10)
# Out:
#         status  card_present_flag       long_lat txn_description first_name  \
# 0   authorized                1.0  153.41 -27.95             POS      Diana
# 1   authorized                0.0  153.41 -27.95       SALES-POS      Diana
# 2   authorized                1.0  151.23 -33.94             POS    Michael
# 3   authorized                1.0  153.10 -27.66       SALES-POS     Rhonda
# 4   authorized                1.0  153.41 -27.95       SALES-POS      Diana
# 6   authorized                1.0  144.95 -37.76       SALES-POS    Kristin
# 7   authorized                1.0  144.95 -37.76             POS    Kristin
# 8   authorized                1.0  116.06 -32.00             POS      Tonya
# 12  authorized                1.0  116.06 -32.00       SALES-POS      Tonya
# 15  authorized                1.0  153.05 -27.61             POS    Jeffrey
#
#     balance gender  age   merchant_suburb merchant_state  amount  \
# 0     35.39      F   26           Ashmore            QLD   16.25
# ...

# %%
#WithOUT POS 
customer2 = ANZ[ANZ['txn_description'].isin(['PAY/SALARY','PAYMENT','INTER BANK','PHONE BANK'])]
customer2.head(10)
# Out:
#     status  card_present_flag       long_lat txn_description first_name  \
# 5   posted                NaN  151.22 -33.87         PAYMENT     Robert
# 9   posted                NaN  151.23 -33.96      INTER BANK    Michael
# 10  posted                NaN  146.94 -36.04         PAYMENT   Fernando
# 11  posted                NaN  144.95 -37.76         PAYMENT    Kristin
# 13  posted                NaN  151.27 -33.76      INTER BANK     Isaiah
# 14  posted                NaN  145.16 -37.84      INTER BANK      Ricky
# 16  posted                NaN  144.99 -37.90      INTER BANK    Patrick
# 17  posted                NaN  149.03 -34.97         PAYMENT      Karen
# 18  posted                NaN  115.72 -32.28         PAYMENT       Ruth
# 25  posted                NaN  151.04 -33.80      INTER BANK  Christine
#
#       balance gender  age merchant_suburb merchant_state  amount  \
# 5     1705.43      M   20             NaN            NaN   163.0
# ...

# %%
ANZ['amount'].plot(kind='hist')
plt.show()

# %%
customer1['amount'].plot(kind='hist')
plt.show()

# %%
customer2['amount'].plot(kind='hist')

# %% [markdown]
# ### daywize

# %%
## overall Dataframe
plt.figure(figsize=(10,4))
sns.barplot('Day','amount',data=ANZ)
plt.show()

# %%
## POS  Dataframe
plt.figure(figsize=(10,4))
sns.barplot('Day','amount',data=customer1)
plt.show()

# %%
## without POS Dataframe
plt.figure(figsize=(10,4))
sns.barplot('Day','amount',data=customer2)
plt.show()

# %% [markdown]
# #### Creating dataframe from thier gender which have salary as their transaction description

# %%
ANZ_salary= ANZ[ANZ['txn_description']=='PAY/SALARY']
#accidents_locations_area_name=get_columns_from_data(accidents_locations_zones, ['DR Number','Area Name'])
male_salary=ANZ_salary[ANZ_salary['gender']=='M']
female_salary=ANZ_salary[ANZ_salary['gender']=='F']

# %% [markdown]
# #### checking their Avg Salary

# %%
average_male_salary=male_salary['amount'].values.mean()
average_female_salary=female_salary['amount'].values.mean()

# %%
average_male_salary
# Out:
# 2096.811681034483

# %%
average_female_salary
# Out:
# 1679.370477326969

# %%
card = ANZ.loc[ANZ.card_present_flag.isnull()]

# %%
card
# Out:
#        status  card_present_flag       long_lat txn_description first_name  \
# 5      posted                NaN  151.22 -33.87         PAYMENT     Robert
# 9      posted                NaN  151.23 -33.96      INTER BANK    Michael
# 10     posted                NaN  146.94 -36.04         PAYMENT   Fernando
# 11     posted                NaN  144.95 -37.76         PAYMENT    Kristin
# 13     posted                NaN  151.27 -33.76      INTER BANK     Isaiah
# ...       ...                ...            ...             ...        ...
# 12027  posted                NaN  144.71 -37.58      PHONE BANK       Luis
# 12032  posted                NaN  150.82 -34.01         PAYMENT   Michelle
# 12035  posted                NaN  115.78 -31.90         PAYMENT    Antonio
# 12036  posted                NaN  145.17 -37.84         PAYMENT    Matthew
# 12037  posted                NaN  121.48 -30.75         PAYMENT    Kenneth
#
# ...

# %%
pd.DataFrame(ANZ.groupby("txn_description")["card_present_flag"].value_counts()).T
# Out:
# txn_description     POS      SALES-POS
# card_present_flag   1.0  0.0       1.0  0.0
# card_present_flag  3025  758      3169  765

# %%
ANZ.groupby("status")["card_present_flag"].value_counts()
# Out:
# status      card_present_flag
# authorized  1.0                  6194
#             0.0                  1523
# Name: card_present_flag, dtype: int64

# %%
sns.heatmap(ANZ.corr(),annot=True)

# %%
sns.pairplot(ANZ)

# %%
sns.pairplot(ANZ,hue='gender')

# %%
sns.pairplot(ANZ,hue='month')
plt.show()

# %%
sns.pairplot(ANZ,hue='Day')
plt.show()

# %%
# dataframe
salary_customer = ANZ[ANZ['txn_description'].isin(['PAY/SALARY'])]
salary_customer.head()
# Out:
#     status  card_present_flag       long_lat txn_description first_name  \
# 50  posted                NaN  151.27 -33.76      PAY/SALARY     Isaiah
# 61  posted                NaN  145.01 -37.93      PAY/SALARY    Marissa
# 64  posted                NaN  151.18 -33.80      PAY/SALARY       Eric
# 68  posted                NaN  145.00 -37.83      PAY/SALARY    Jeffrey
# 70  posted                NaN  144.95 -37.76      PAY/SALARY    Kristin
#
#     balance gender  age merchant_suburb merchant_state   amount  \
# 50  8342.11      M   23             NaN            NaN  3903.95
# 61  2040.58      F   23             NaN            NaN  1626.48
# 64  3158.51      M   22             NaN            NaN   983.36
# 68  2517.66      M   24             NaN            NaN  1408.08
# 70  2271.79      F   43             NaN            NaN  1068.04
#
#                       transaction_id     customer_id merchant_long_lat  \
# 50  9ca281650e5d482d9e53f85e959baa66  CUS-1462656821               NaN
# ...

# %%
print('The Shape of salary customer Dataset is ', salary_customer.shape)
# Out:
# The Shape of salary customer Dataset is  (883, 18)

# %%
customer1.isnull().sum()
# Out:
# status               0
# card_present_flag    0
# long_lat             0
# txn_description      0
# first_name           0
# balance              0
# gender               0
# age                  0
# merchant_suburb      0
# merchant_state       0
# amount               0
# transaction_id       0
# customer_id          0
# merchant_long_lat    0
# movement             0
# Trans_date           0
# month                0
# Day                  0
# dtype: int64

# %%
pd.DataFrame(customer1.groupby("merchant_state")["amount"].count()).plot(kind='bar')

# %%
customer1['status'].value_counts()
# Out:
# authorized    7717
# Name: status, dtype: int64

# %%
salary_customer.isnull().sum()
# Out:
# status                 0
# card_present_flag    883
# long_lat               0
# txn_description        0
# first_name             0
# balance                0
# gender                 0
# age                    0
# merchant_suburb      883
# merchant_state       883
# amount                 0
# transaction_id         0
# customer_id            0
# merchant_long_lat    883
# movement               0
# Trans_date             0
# month                  0
# Day                    0
# dtype: int64

# %%
salary_customer['status'].value_counts()
# Out:
# posted    883
# Name: status, dtype: int64

# %% [markdown]
# ### Modeling

# %%
NEW=ANZ[ANZ['txn_description']=='PAY/SALARY']

# %%
NEW.head(),NEW.shape
# Out:
# (    status  card_present_flag       long_lat txn_description first_name  \
#  50  posted                NaN  151.27 -33.76      PAY/SALARY     Isaiah
#  61  posted                NaN  145.01 -37.93      PAY/SALARY    Marissa
#  64  posted                NaN  151.18 -33.80      PAY/SALARY       Eric
#  68  posted                NaN  145.00 -37.83      PAY/SALARY    Jeffrey
#  70  posted                NaN  144.95 -37.76      PAY/SALARY    Kristin
#
#      balance gender  age merchant_suburb merchant_state   amount  \
#  50  8342.11      M   23             NaN            NaN  3903.95
#  61  2040.58      F   23             NaN            NaN  1626.48
#  64  3158.51      M   22             NaN            NaN   983.36
#  68  2517.66      M   24             NaN            NaN  1408.08
#  70  2271.79      F   43             NaN            NaN  1068.04
#
#                        transaction_id     customer_id merchant_long_lat  \
# ...

# %%
for i in NEW:
    print('The column name is',i,' the unique element is ,',NEW[i].nunique())
# Out:
# The column name is status  the unique element is , 1
# The column name is card_present_flag  the unique element is , 0
# The column name is long_lat  the unique element is , 100
# The column name is txn_description  the unique element is , 1
# The column name is first_name  the unique element is , 80
# The column name is balance  the unique element is , 883
# The column name is gender  the unique element is , 2
# The column name is age  the unique element is , 33
# The column name is merchant_suburb  the unique element is , 0
# The column name is merchant_state  the unique element is , 0
# The column name is amount  the unique element is , 100
# The column name is transaction_id  the unique element is , 883
# The column name is customer_id  the unique element is , 100
# The column name is merchant_long_lat  the unique element is , 0
# The column name is movement  the unique element is , 1
# The column name is Trans_date  the unique element is , 65
# ...

# %%
## Removing unwanted features

# %%
NEW=NEW.drop(['status','card_present_flag','txn_description','first_name','merchant_suburb',
              'merchant_state','movement','Trans_date','merchant_long_lat','long_lat'],axis=1)

# %%
NEW.head()
# Out:
#     balance gender  age   amount                    transaction_id  \
# 50  8342.11      M   23  3903.95  9ca281650e5d482d9e53f85e959baa66
# 61  2040.58      F   23  1626.48  1822eb0e1bbe4c9e95ebbb0fa2cc4323
# 64  3158.51      M   22   983.36  bd62b1799a454cedbbb56364f7c40cbf
# 68  2517.66      M   24  1408.08  0d95c7c932bb48e5b44c2637bdd3efe9
# 70  2271.79      F   43  1068.04  f50ccf1195214d14a0acbfcb5a265193
#
#        customer_id  month  Day
# 50  CUS-1462656821      8    2
# 61  CUS-2500783281      8    2
# 64   CUS-326006476      8    2
# 68  CUS-1433879684      8    2
# 70  CUS-4123612273      8    2

# %%
NEW_1=NEW.groupby('customer_id').mean()

# %%
NEW_1.head()
# Out:
#                      balance   age   amount     month  Day
# customer_id
# CUS-1005756958   4718.665385  53.0   970.47  9.076923  1.0
# CUS-1117979751  11957.202857  21.0  3578.65  9.142857  0.0
# CUS-1140341822   5841.720000  28.0  1916.51  9.000000  4.0
# CUS-1147642491   8813.467692  34.0  1711.39  9.076923  0.0
# CUS-1196156254  23845.717143  34.0  3903.73  8.857143  2.0

# %%
salaries = []

for customer_id in NEW["customer_id"]:
    salaries.append(int(NEW_1.loc[customer_id]["amount"]))

# %%
    NEW['Annual salary'] = NEW['amount']*12

# %%
df = NEW.groupby("customer_id").mean()
df.head()
# Out:
#                      balance   age   amount     month  Day  Annual salary
# customer_id
# CUS-1005756958   4718.665385  53.0   970.47  9.076923  1.0       11645.64
# CUS-1117979751  11957.202857  21.0  3578.65  9.142857  0.0       42943.80
# CUS-1140341822   5841.720000  28.0  1916.51  9.000000  4.0       22998.12
# CUS-1147642491   8813.467692  34.0  1711.39  9.076923  0.0       20536.68
# CUS-1196156254  23845.717143  34.0  3903.73  8.857143  2.0       46844.76

# %%
NEW=pd.get_dummies(NEW,drop_first=True)

# %%
NEW
# Out:
#         balance  age   amount  month  Day  Annual salary  gender_M  \
# 50      8342.11   23  3903.95      8    2       46847.40         1
# 61      2040.58   23  1626.48      8    2       19517.76         0
# 64      3158.51   22   983.36      8    2       11800.32         1
# 68      2517.66   24  1408.08      8    2       16896.96         1
# 70      2271.79   43  1068.04      8    2       12816.48         0
# ...         ...  ...      ...    ...  ...            ...       ...
# 11995   9378.51   26  1098.91     10    2       13186.92         1
# 12000   3440.01   30  1158.15     10    2       13897.80         0
# 12001  11381.44   69  1043.12     10    2       12517.44         1
# 12003  11454.52   20  1395.49     10    2       16745.88         0
# 12004  19893.45   19  2639.76     10    2       31677.12         1
#
#        transaction_id_00e97a9be9654405bb44f96e748b3ace  \
# 50                                                   0
# ...

# %%
NEW.shape
# Out:
# (883, 988)

# %% [markdown]
# # ML

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %% [markdown]
# ## LINEAR REGRESSION

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Annual salary',axis=1)
y=df['Annual salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=2)

# %%
linear_reg = LinearRegression()

# %%
linear_reg.fit(X_train, y_train)
linear_reg.score(X_train, y_train)
# Out:
# 1.0

# %%
linear_reg.predict(X_test)
# Out:
# array([ 12816.48,  27704.04,  30537.12,  14703.96,  30000.  ,   6912.  ,
#         22998.12, 106031.76,   9135.96,  46847.4 ,  47729.52,  30874.92,
#         23147.64,  43794.12,  11645.64,   9389.04,  20536.68,  34648.08,
#         11954.88,  15269.64,  36323.4 ,  12517.44,  42211.32,  61242.12,
#         49586.76,  27388.32,  58363.44,  38340.12,  12718.08,  31056.12,
#         16754.76,  42943.8 ,  10705.08,  23358.84,  12025.56,  18452.16,
#          7155.96,  11792.52,  50592.48,  45429.36])

# %%
linear_reg.score(X_test, y_test)
# Out:
# 1.0

# %%
decision_tree_reg = DecisionTreeRegressor()

# %%
decision_tree_reg.fit(X_train, y_train)
decision_tree_reg.score(X_train, y_train)
# Out:
# 1.0

# %%
decision_tree_reg.predict(X_test)
# Out:
# array([13186.92, 27843.6 , 30464.16, 13897.8 , 29645.4 ,  7973.16,
#        22571.4 , 72293.88,  8703.84, 44550.72, 52863.6 , 30464.16,
#        23427.48, 46844.76, 12164.04,  7973.16, 20178.96, 34638.24,
#        12164.04, 13897.8 , 36853.68, 12164.04, 52863.6 , 58930.8 ,
#        52863.6 , 27364.32, 58930.8 , 39945.24, 12164.04, 30464.16,
#        16745.88, 52863.6 , 10355.4 , 23427.48, 12164.04, 18722.4 ,
#         7973.16, 12444.84, 52863.6 , 46844.76])

# %%
decision_tree_reg.score(X_test, y_test)
# Out:
# 0.9068903349144362
